# %% [markdown]
# # CH03.3. **Advanced Architecutre**

# %% [markdown]
# > ## **1v1 Convolution Layer**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Residual Block**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Inception Block**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Depth-wise, Point-wise Convolution**
